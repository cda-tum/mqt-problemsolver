# %% [markdown]
# # Kakuro

# %%
from src.mqt.problemsolver.kakuro import Kakuro

# %%
kakuro = Kakuro(1, 3, 3, 1)
kakuro.solve()
# Out:
# Complete Oracle (CX):  290
# Complete Oracle (U):  316
# grover_iterations:  5
# /Users/nils/miniforge3/envs/tf3/lib/python3.9/site-packages/numpy/linalg/linalg.py:2158: RuntimeWarning: divide by zero encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Users/nils/miniforge3/envs/tf3/lib/python3.9/site-packages/numpy/linalg/linalg.py:2158: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# Solution found
#      |  1  |  3  |
# ------------------
#   3  |  0  |  3  |
# ------------------
#   1  |  1  |  0  |
# ------------------

# %% [markdown]
# # TSP

# %%
from src.mqt.problemsolver.tsp import TSP

# %%
tsp = TSP()
tsp.print_problem()

# %%
tsp.solve(1, 2, 3, 3, 3, 3, num_qubits_qft=8)
# Out:
# Eigenstate:  11000110
# Most frequent Binary:  10101011
# Most frequent Decimal:  171
# Phase:  0.66796875
# Route:  [4, 1, 2, 3]
# Costs:  10.01953125
# Eigenstate:  10001101
# Most frequent Binary:  10000100
# Most frequent Decimal:  132
# Phase:  0.515625
# Route:  [3, 1, 4, 2]
# Costs:  7.734375
# Eigenstate:  10000111
# Most frequent Binary:  01100110
# Most frequent Decimal:  102
# Phase:  0.3984375
# Route:  [3, 1, 2, 4]
# Costs:  5.9765625
# ### Solution:  [3, 1, 2, 4]

# %%
tsp.show_classical_result()
