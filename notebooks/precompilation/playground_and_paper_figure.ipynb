# %% [markdown]
# # Playground MaxCut

# %%
from mqt.problemsolver.partialcompiler.qaoa import QAOA
import numpy as np
from time import time
from mqt.qcec import verify

# %%
q = QAOA(num_qubits=9, repetitions=3, sample_probability=0.3, considered_following_qubits=1)
qc_compiled_with_all_gates = q.qc_compiled.copy()

print("Start New")
start = time()
compiled_qc = q.remove_unnecessary_gates(
    qc=qc_compiled_with_all_gates,
    optimize_swaps=True
)
time_new_scheme = time() - start

print("Start Baseline")
start = time()
qc_baseline_compiled = q.compile_qc(baseline=True, opt_level=1)
time_baseline = time() - start

time_ratio = time_new_scheme / time_baseline
if qc_baseline_compiled.count_ops().get("cx"):
    cx_count_ratio = compiled_qc.count_ops()["cx"] / qc_baseline_compiled.count_ops()["cx"]
else:
    cx_count_ratio = 0
# print("QCEC:", verify(q.qc_baseline, qc_baseline_compiled))
print (np.round(time_ratio,5), np.round(cx_count_ratio,3))
# Out:
# /Users/nils/miniforge3/envs/Precompilation/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: divide by zero encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Users/nils/miniforge3/envs/Precompilation/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# Start New
# Start Baseline
# 0.01201 1.067

# %%
print(verify(compiled_qc, qc_baseline_compiled))
# Out:
# {
#   "check_time": 0.002454916,
#   "equivalence": "equivalent_up_to_global_phase",
#   "parameterized": {
#     "performed_instantiations": 0
#   },
#   "preprocessing_time": 0.000246291
# }

# %% [markdown]
# # Playground Satellite Use-Case

# %%
s = QAOA(num_qubits=3, repetitions=3, sample_probability=0.3, considered_following_qubits=3, satellite_use_case=True)
qc_compiled_with_all_gates = s.qc_compiled.copy()

print("Start New")
start = time()
compiled_qc = s.remove_unnecessary_gates(
    qc=qc_compiled_with_all_gates,
    optimize_swaps=True
)
time_new_scheme = time() - start

print("Start Baseline")
start = time()
qc_baseline_compiled = s.compile_qc(baseline=True, opt_level=3)
time_baseline = time() - start

time_ratio = time_new_scheme / time_baseline
if qc_baseline_compiled.count_ops().get("cx"):
    cx_count_ratio = compiled_qc.count_ops()["cx"] / qc_baseline_compiled.count_ops()["cx"]
else:
    cx_count_ratio = 0
# print("QCEC:", verify(q.qc_baseline, qc_baseline_compiled))
print (np.round(time_ratio,5), np.round(cx_count_ratio,3))
# Out:
# Start New
# Start Baseline
# /Users/nils/miniforge3/envs/Precompilation/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: divide by zero encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Users/nils/miniforge3/envs/Precompilation/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Users/nils/Documents/repos/MQTProblemSolver/src/mqt/problemsolver/partialcompiler/qaoa.py:151: ComplexWarning: Casting complex values to real discards the imaginary part
#   coeffs = np.array(ising[0].primitive.coeffs, dtype=float)
# /Users/nils/miniforge3/envs/Precompilation/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: divide by zero encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Users/nils/miniforge3/envs/Precompilation/lib/python3.10/site-packages/numpy/linalg/linalg.py:2154: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# 0.27265 2.0

# %%
print("QCEC:", verify(compiled_qc, qc_baseline_compiled))
# Out:
# QCEC: {
#   "check_time": 0.000920167,
#   "equivalence": "equivalent",
#   "parameterized": {
#     "performed_instantiations": 0
#   },
#   "preprocessing_time": 0.000483833
# }

# %%
qc_baseline_compiled.draw()
# Out:
# global phase: π/4
#                ┌─────────┐┌────┐┌─────────┐┌────────────────────────┐     »
#       q_2 -> 0 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ Rz(-1.0*qubit_2_rep_0) ├─────»
#                ├─────────┤├────┤├─────────┤├────────────────────────┤┌───┐»
#       q_1 -> 1 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ Rz(-3.0*qubit_1_rep_0) ├┤ X ├»
#                ├─────────┤├────┤├─────────┤├────────────────────────┤└─┬─┘»
#       q_0 -> 2 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ Rz(-1.0*qubit_0_rep_0) ├──■──»
#                └─────────┘└────┘└─────────┘└────────────────────────┘     »
# ancilla_0 -> 3 ───────────────────────────────────────────────────────────»
#                                                                           »
# ancilla_1 -> 4 ───────────────────────────────────────────────────────────»
#                                                                           »
#        meas: 3/═══════════════════════════════════════════════════════════»
#                                                                           »
# «                                      ┌───┐   ┌─────────────┐      ┌───┐      »
# «      q_2 -> 0 ───────────────────────┤ X ├───┤ Rz(2.0*a_2) ├──────┤ X ├──────»
# «               ┌─────────────┐┌───┐   └─┬─┘   └─────────────┘      └─┬─┘      »
# «      q_1 -> 1 ┤ Rz(2.0*a_0) ├┤ X ├─────■────────────────────────────■────────»
# «               └─────────────┘└─┬─┘┌─────────┐     ┌────┐    ┌───────────────┐»
# «      q_0 -> 2 ─────────────────■──┤ Rz(π/2) ├─────┤ √X ├────┤ Rz(2*b_0 + π) ├»
# «                                   └─────────┘     └────┘    └───────────────┘»
# «ancilla_0 -> 3 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «ancilla_1 -> 4 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «       meas: 3/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «               ┌─────────┐   ┌────┐       ┌───────────────┐     ┌────┐»
# «      q_2 -> 0 ┤ Rz(π/2) ├───┤ √X ├───────┤ Rz(2*b_0 + π) ├─────┤ √X ├»
# «               ├─────────┤   ├────┤       ├───────────────┤     ├────┤»
# «      q_1 -> 1 ┤ Rz(π/2) ├───┤ √X ├───────┤ Rz(2*b_0 + π) ├─────┤ √X ├»
# «               └──┬────┬─┘┌──┴────┴──┐┌───┴───────────────┴────┐└────┘»
# «      q_0 -> 2 ───┤ √X ├──┤ Rz(5π/2) ├┤ Rz(-1.0*qubit_0_rep_1) ├──────»
# «                  └────┘  └──────────┘└────────────────────────┘      »
# «ancilla_0 -> 3 ───────────────────────────────────────────────────────»
# «                                                                      »
# «ancilla_1 -> 4 ───────────────────────────────────────────────────────»
# «                                                                      »
# «       meas: 3/═══════════════════════════════════════════════════════»
# «                                                                      »
# «               ┌──────────┐┌────────────────────────┐                         »
# «      q_2 -> 0 ┤ Rz(5π/2) ├┤ Rz(-1.0*qubit_2_rep_1) ├─────────────────────────»
# «               ├──────────┤├────────────────────────┤┌───┐┌─────────────┐┌───┐»
# «      q_1 -> 1 ┤ Rz(5π/2) ├┤ Rz(-3.0*qubit_1_rep_1) ├┤ X ├┤ Rz(2.0*a_3) ├┤ X ├»
# «               └──────────┘└────────────────────────┘└─┬─┘└─────────────┘└─┬─┘»
# «      q_0 -> 2 ────────────────────────────────────────■───────────────────■──»
# «                                                                              »
# «ancilla_0 -> 3 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «ancilla_1 -> 4 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «       meas: 3/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                  ┌───┐   ┌─────────────┐      ┌───┐      ┌─────────┐»
# «      q_2 -> 0 ───┤ X ├───┤ Rz(2.0*a_5) ├──────┤ X ├──────┤ Rz(π/2) ├»
# «                  └─┬─┘   └─────────────┘      └─┬─┘      ├─────────┤»
# «      q_1 -> 1 ─────■────────────────────────────■────────┤ Rz(π/2) ├»
# «               ┌─────────┐     ┌────┐    ┌───────────────┐└──┬────┬─┘»
# «      q_0 -> 2 ┤ Rz(π/2) ├─────┤ √X ├────┤ Rz(2*b_1 + π) ├───┤ √X ├──»
# «               └─────────┘     └────┘    └───────────────┘   └────┘  »
# «ancilla_0 -> 3 ──────────────────────────────────────────────────────»
# «                                                                     »
# «ancilla_1 -> 4 ──────────────────────────────────────────────────────»
# «                                                                     »
# «       meas: 3/══════════════════════════════════════════════════════»
# «                                                                     »
# «                  ┌────┐       ┌───────────────┐     ┌────┐┌──────────┐»
# «      q_2 -> 0 ───┤ √X ├───────┤ Rz(2*b_1 + π) ├─────┤ √X ├┤ Rz(5π/2) ├»
# «                  ├────┤       ├───────────────┤     ├────┤├──────────┤»
# «      q_1 -> 1 ───┤ √X ├───────┤ Rz(2*b_1 + π) ├─────┤ √X ├┤ Rz(5π/2) ├»
# «               ┌──┴────┴──┐┌───┴───────────────┴────┐└────┘└──────────┘»
# «      q_0 -> 2 ┤ Rz(5π/2) ├┤ Rz(-1.0*qubit_0_rep_2) ├──────────────────»
# «               └──────────┘└────────────────────────┘                  »
# «ancilla_0 -> 3 ────────────────────────────────────────────────────────»
# «                                                                       »
# «ancilla_1 -> 4 ────────────────────────────────────────────────────────»
# «                                                                       »
# «       meas: 3/════════════════════════════════════════════════════════»
# «                                                                       »
# «               ┌────────────────────────┐                            ┌───┐   »
# «      q_2 -> 0 ┤ Rz(-1.0*qubit_2_rep_2) ├────────────────────────────┤ X ├───»
# «               ├────────────────────────┤┌───┐┌─────────────┐┌───┐   └─┬─┘   »
# «      q_1 -> 1 ┤ Rz(-3.0*qubit_1_rep_2) ├┤ X ├┤ Rz(2.0*a_6) ├┤ X ├─────■─────»
# «               └────────────────────────┘└─┬─┘└─────────────┘└─┬─┘┌─────────┐»
# «      q_0 -> 2 ────────────────────────────■───────────────────■──┤ Rz(π/2) ├»
# «                                                                  └─────────┘»
# «ancilla_0 -> 3 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «ancilla_1 -> 4 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «       meas: 3/══════════════════════════════════════════════════════════════»
# «                                                                             »
# «               ┌─────────────┐      ┌───┐      ┌─────────┐   ┌────┐   »
# «      q_2 -> 0 ┤ Rz(2.0*a_8) ├──────┤ X ├──────┤ Rz(π/2) ├───┤ √X ├───»
# «               └─────────────┘      └─┬─┘      ├─────────┤   ├────┤   »
# «      q_1 -> 1 ───────────────────────■────────┤ Rz(π/2) ├───┤ √X ├───»
# «                    ┌────┐    ┌───────────────┐└──┬────┬─┘┌──┴────┴──┐»
# «      q_0 -> 2 ─────┤ √X ├────┤ Rz(2*b_2 + π) ├───┤ √X ├──┤ Rz(5π/2) ├»
# «                    └────┘    └───────────────┘   └────┘  └──────────┘»
# «ancilla_0 -> 3 ───────────────────────────────────────────────────────»
# «                                                                      »
# «ancilla_1 -> 4 ───────────────────────────────────────────────────────»
# «                                                                      »
# «       meas: 3/═══════════════════════════════════════════════════════»
# «                                                                      »
# «               ┌───────────────┐┌────┐┌──────────┐ ░       ┌─┐
# «      q_2 -> 0 ┤ Rz(2*b_2 + π) ├┤ √X ├┤ Rz(5π/2) ├─░───────┤M├
# «               ├───────────────┤├────┤├──────────┤ ░    ┌─┐└╥┘
# «      q_1 -> 1 ┤ Rz(2*b_2 + π) ├┤ √X ├┤ Rz(5π/2) ├─░────┤M├─╫─
# «               └───────────────┘└────┘└──────────┘ ░ ┌─┐└╥┘ ║
# «      q_0 -> 2 ────────────────────────────────────░─┤M├─╫──╫─
# «                                                   ░ └╥┘ ║  ║
# «ancilla_0 -> 3 ───────────────────────────────────────╫──╫──╫─
# «                                                      ║  ║  ║
# «ancilla_1 -> 4 ───────────────────────────────────────╫──╫──╫─
# «                                                      ║  ║  ║
# «       meas: 3/═══════════════════════════════════════╩══╩══╩═
# «                                                      0  1  2

# %%
compiled_qc.draw()
# Out:
# global phase: π/4
#                ┌─────────┐┌────┐┌─────────┐┌────────────────────────┐     »
#       q_2 -> 0 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ Rz(-1.0*qubit_2_rep_0) ├─────»
#                ├─────────┤├────┤├─────────┤├────────────────────────┤     »
#       q_0 -> 1 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ Rz(-1.0*qubit_0_rep_0) ├──■──»
#                ├─────────┤├────┤├─────────┤├────────────────────────┤┌─┴─┐»
#       q_1 -> 2 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ Rz(-3.0*qubit_1_rep_0) ├┤ X ├»
#                └─────────┘└────┘└─────────┘└────────────────────────┘└───┘»
# ancilla_0 -> 3 ───────────────────────────────────────────────────────────»
#                                                                           »
# ancilla_1 -> 4 ───────────────────────────────────────────────────────────»
#                                                                           »
#        meas: 3/═══════════════════════════════════════════════════════════»
#                                                                           »
# «                                                                           »
# «      q_2 -> 0 ────────────────────────────────────────────────────────────»
# «                                   ┌─────────┐┌────┐┌───────────────┐┌────┐»
# «      q_0 -> 1 ─────────────────■──┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_0 + π) ├┤ √X ├»
# «               ┌─────────────┐┌─┴─┐└─────────┘└────┘└───────────────┘└────┘»
# «      q_1 -> 2 ┤ Rz(2.0*a_0) ├┤ X ├────────────────────────────────────────»
# «               └─────────────┘└───┘                                        »
# «ancilla_0 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «       meas: 3/════════════════════════════════════════════════════════════»
# «                                                                           »
# «                                                                    ┌───┐»
# «      q_2 -> 0 ─────────────────────────────────────────────────────┤ X ├»
# «               ┌──────────┐┌────────────────────────┐     ┌───┐     └─┬─┘»
# «      q_0 -> 1 ┤ Rz(5π/2) ├┤ Rz(-1.0*qubit_0_rep_1) ├──■──┤ X ├──■────■──»
# «               └──────────┘└────────────────────────┘┌─┴─┐└─┬─┘┌─┴─┐     »
# «      q_1 -> 2 ──────────────────────────────────────┤ X ├──■──┤ X ├─────»
# «                                                     └───┘     └───┘     »
# «ancilla_0 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_1 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «       meas: 3/══════════════════════════════════════════════════════════»
# «                                                                         »
# «               ┌─────────────┐┌───┐┌─────────┐┌────┐┌───────────────┐┌────┐»
# «      q_2 -> 0 ┤ Rz(2.0*a_2) ├┤ X ├┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_0 + π) ├┤ √X ├»
# «               └─────────────┘└─┬─┘├─────────┤├────┤├───────────────┤├────┤»
# «      q_0 -> 1 ─────────────────■──┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_0 + π) ├┤ √X ├»
# «                                   └─────────┘└────┘└───────────────┘└────┘»
# «      q_1 -> 2 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «       meas: 3/════════════════════════════════════════════════════════════»
# «                                                                           »
# «               ┌──────────┐┌────────────────────────┐                         »
# «      q_2 -> 0 ┤ Rz(5π/2) ├┤ Rz(-1.0*qubit_2_rep_1) ├─────────────────────────»
# «               ├──────────┤├────────────────────────┤┌───┐┌─────────────┐┌───┐»
# «      q_0 -> 1 ┤ Rz(5π/2) ├┤ Rz(-3.0*qubit_1_rep_1) ├┤ X ├┤ Rz(2.0*a_3) ├┤ X ├»
# «               └──────────┘└────────────────────────┘└─┬─┘└─────────────┘└─┬─┘»
# «      q_1 -> 2 ────────────────────────────────────────■───────────────────■──»
# «                                                                              »
# «ancilla_0 -> 3 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «ancilla_1 -> 4 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «       meas: 3/═══════════════════════════════════════════════════════════════»
# «                                                                              »
# «                          ┌───┐                                       »
# «      q_2 -> 0 ─────■─────┤ X ├─────────■──────────■──────────────────»
# «                  ┌─┴─┐   └─┬─┘       ┌─┴─┐      ┌─┴─┐ ┌─────────────┐»
# «      q_0 -> 1 ───┤ X ├─────■─────────┤ X ├──────┤ X ├─┤ Rz(2.0*a_5) ├»
# «               ┌──┴───┴──┐┌────┐┌─────┴───┴─────┐├───┴┐└─┬──────────┬┘»
# «      q_1 -> 2 ┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_1 + π) ├┤ √X ├──┤ Rz(5π/2) ├─»
# «               └─────────┘└────┘└───────────────┘└────┘  └──────────┘ »
# «ancilla_0 -> 3 ───────────────────────────────────────────────────────»
# «                                                                      »
# «ancilla_1 -> 4 ───────────────────────────────────────────────────────»
# «                                                                      »
# «       meas: 3/═══════════════════════════════════════════════════════»
# «                                                                      »
# «                                         ┌─────────┐┌────┐┌───────────────┐»
# «      q_2 -> 0 ────────────■─────────────┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_1 + π) ├»
# «                         ┌─┴─┐           ├─────────┤├────┤├───────────────┤»
# «      q_0 -> 1 ──────────┤ X ├───────────┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_1 + π) ├»
# «               ┌─────────┴───┴──────────┐└─────────┘└────┘└───────────────┘»
# «      q_1 -> 2 ┤ Rz(-1.0*qubit_0_rep_2) ├──────────────────────────────────»
# «               └────────────────────────┘                                  »
# «ancilla_0 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «       meas: 3/════════════════════════════════════════════════════════════»
# «                                                                           »
# «               ┌────┐┌──────────┐┌────────────────────────┐┌───┐     ┌───┐»
# «      q_2 -> 0 ┤ √X ├┤ Rz(5π/2) ├┤ Rz(-3.0*qubit_1_rep_2) ├┤ X ├──■──┤ X ├»
# «               ├────┤├──────────┤├────────────────────────┤└─┬─┘┌─┴─┐└─┬─┘»
# «      q_0 -> 1 ┤ √X ├┤ Rz(5π/2) ├┤ Rz(-1.0*qubit_2_rep_2) ├──■──┤ X ├──■──»
# «               └────┘└──────────┘└────────────────────────┘     └───┘     »
# «      q_1 -> 2 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_0 -> 3 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_1 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «       meas: 3/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                   ┌───┐                  »
# «      q_2 -> 0 ──────────────────────────────■─────┤ X ├─────────■────────»
# «               ┌───┐┌─────────────┐┌───┐   ┌─┴─┐   └─┬─┘       ┌─┴─┐      »
# «      q_0 -> 1 ┤ X ├┤ Rz(2.0*a_6) ├┤ X ├───┤ X ├─────■─────────┤ X ├──────»
# «               └─┬─┘└─────────────┘└─┬─┘┌──┴───┴──┐┌────┐┌─────┴───┴─────┐»
# «      q_1 -> 2 ──■───────────────────■──┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_2 + π) ├»
# «                                        └─────────┘└────┘└───────────────┘»
# «ancilla_0 -> 3 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_1 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «       meas: 3/═══════════════════════════════════════════════════════════»
# «                                                                          »
# «                                         ┌─────────┐┌────┐┌───────────────┐»
# «      q_2 -> 0 ──■────────────────────■──┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_2 + π) ├»
# «               ┌─┴─┐ ┌─────────────┐┌─┴─┐├─────────┤├────┤├───────────────┤»
# «      q_0 -> 1 ┤ X ├─┤ Rz(2.0*a_8) ├┤ X ├┤ Rz(π/2) ├┤ √X ├┤ Rz(2*b_2 + π) ├»
# «               ├───┴┐└─┬──────────┬┘└───┘└─────────┘└────┘└───────────────┘»
# «      q_1 -> 2 ┤ √X ├──┤ Rz(5π/2) ├────────────────────────────────────────»
# «               └────┘  └──────────┘                                        »
# «ancilla_0 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «       meas: 3/════════════════════════════════════════════════════════════»
# «                                                                           »
# «               ┌────┐┌──────────┐ ░    ┌─┐
# «      q_2 -> 0 ┤ √X ├┤ Rz(5π/2) ├─░────┤M├───
# «               ├────┤├──────────┤ ░    └╥┘┌─┐
# «      q_0 -> 1 ┤ √X ├┤ Rz(5π/2) ├─░─────╫─┤M├
# «               └────┘└──────────┘ ░ ┌─┐ ║ └╥┘
# «      q_1 -> 2 ───────────────────░─┤M├─╫──╫─
# «                                  ░ └╥┘ ║  ║
# «ancilla_0 -> 3 ──────────────────────╫──╫──╫─
# «                                     ║  ║  ║
# «ancilla_1 -> 4 ──────────────────────╫──╫──╫─
# «                                     ║  ║  ║
# «       meas: 3/══════════════════════╩══╩══╩═
# «                                     0  1  2

# %% [markdown]
# # Paper Example

# %%
from qiskit import transpile, QuantumCircuit
from qiskit.providers.fake_provider import FakeQuito, FakeManila
from qiskit.circuit import Parameter
cmap = FakeQuito().configuration().coupling_map
cmap
p = Parameter("p")

# %%
qc = QuantumCircuit(4)
qc.rzz(p, 0,1)
qc.rzz(p, 0,2)
qc.rzz(p, 0,3)
qc.rzz(p, 1,2)
qc.rzz(p, 1,3)
qc.rzz(p, 2,3)
qc.draw()
# Out:
#
# q_0: ─■───────■───────■──────────────────────────────
#       │ZZ(p)  │       │
# q_1: ─■───────┼───────┼───────■───────■──────────────
#               │ZZ(p)  │       │ZZ(p)  │
# q_2: ─────────■───────┼───────■───────┼───────■──────
#                       │ZZ(p)          │ZZ(p)  │ZZ(p)
# q_3: ─────────────────■───────────────■───────■──────

# %%
qc = transpile(qc, coupling_map=cmap, optimization_level=3)
print(qc.draw())
print(qc.count_ops()["swap"])
# Out:
#
#       q_1 -> 0 ─■───────────────────────X────────────────────────────
#                 │ZZ(p)                  │
#       q_0 -> 1 ─■───────■───────■───────X──■───────■───────X──■──────
#                         │       │ZZ(p)     │       │ZZ(p)  │  │
#       q_3 -> 2 ─────────┼───────■──────────┼───────■───────X──┼──────
#                         │ZZ(p)             │ZZ(p)             │ZZ(p)
#       q_2 -> 3 ─────────■──────────────────■──────────────────■──────
#
# ancilla_0 -> 4 ──────────────────────────────────────────────────────
#
# 2

# %%
qc = QuantumCircuit(4)
qc.rzz(p, 0,1)
qc.rzz(p, 0,2)
#qc.rzz(p, 0,3)
qc.rzz(p, 1,2)
#qc.rzz(p, 1,3)
qc.rzz(p, 2,3)
qc.draw()
qc = transpile(qc, coupling_map=cmap, optimization_level=3)
print(qc.draw())
print(qc.count_ops()["swap"])
# Out:
#
# ancilla_0 -> 0 ───────────────────────────────────
#
#       q_0 -> 1 ─■───────■───────X──■──────────────
#                 │ZZ(p)  │       │  │
#       q_1 -> 2 ─■───────┼───────X──┼──────────────
#                         │ZZ(p)     │ZZ(p)
#       q_2 -> 3 ─────────■──────────■───────■──────
#                                            │ZZ(p)
#       q_3 -> 4 ────────────────────────────■──────
#
# 1
